# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import holoviews as hv
import geopandas as gpd

# Import API key
from api_keys import geoapify_key



# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %%
min_Lat = city_data_df["Lat"].min()
max_Lat = city_data_df["Lat"].max()
min_Lng = city_data_df["Lng"].min()
max_Lng = city_data_df["Lng"].max()

print(f"minumun latitude {min_Lat}")
print(f"maximun latitude {max_Lat}")
print(f"minumun longitude {min_Lng}")
print(f"maximun longitude {max_Lng}")
# Out:
# minumun latitude -54.8
# maximun latitude 78.2186
# minumun longitude -179.1667
# maximun longitude 179.3167

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Create a GeoDataFrame with Point geometries
city_data_df['geometry'] = gpd.points_from_xy(city_data_df['Lng'], city_data_df['Lat'])
# Convert to a GeoDataFrame
city_data_gdf = gpd.GeoDataFrame(city_data_df, geometry='geometry')
city_data_gdf
# Out:
#      City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          0         faya  18.3851   42.4509     22.06        35          21
# 1          1      farsund  58.0948    6.8047     13.30       100           0
# 2          2  new norfolk -42.7826  147.0587     11.72        58          12
# 3          3    jamestown  42.0970  -79.2353      5.77        77         100
# 4          4      lanzhou  36.0564  103.7922     14.53        48          59
# ..       ...          ...      ...       ...       ...       ...         ...
# 572      572    sovetskiy  61.3614   63.5842      3.93        96         100
# 573      573      tatarsk  55.2190   75.9828      3.78        89          84
# 574      574    canchungo  12.0672  -16.0333     35.07        61          67
# 575      575      iquique -20.2208  -70.1431     17.02        68           6
# 576      576         poum -20.2333  164.0167     23.91        79          23
#
# ...

# %%
#%%capture --no-display

# Set the plotting backend to Bokeh
hv.extension('bokeh')

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    geo=True,
    x='Lng',
    y='Lat',
    size='Humidity',
    title='City Humidity Map',
    hover_cols=['City', 'Humidity'],
    color='Humidity',
    cmap='viridis_r',
    alpha=0.3,
    tiles="OSM"
)

# Display the city names as labels on the points
#labels = hv.Labels(city_data_df, ['City'])
#map_plot_1 * labels.opts(text_font_size='10pt', text_color='black')


# Display the map
map_plot_1.opts(width=1000, height=800)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# Defining weather condition criteria
max_temp_condition = (city_data_df['Max Temp'] >= 20) & (city_data_df['Max Temp'] <= 25)  # Comfortable temperature
#humidity_condition = city_data_df['Humidity'] <= 50  # Moderate humidity
#cloudiness_condition = city_data_df['Cloudiness'] <= 20  # Low cloudiness
#wind_speed_condition = city_data_df['Wind Speed'] <= 5  # Gentle wind speed

# Apply the conditions to filter the DataFrame
suitable_cities_df = city_data_df[max_temp_condition]# & humidity_condition & cloudiness_condition & wind_speed_condition]

# Display the DataFrame with suitable weather conditions
#print(suitable_cities_df)
suitable_cities_df

# Drop any rows with null values
suitable_cities_df = suitable_cities_df.dropna()

# Display the DataFrame after dropping null values
suitable_cities_df
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 0          0           faya  18.3851   42.4509     22.06        35
# 7          7      carnarvon -24.8667  113.6333     20.02        76
# 9          9   saint-pierre -21.3393   55.4781     22.82        68
# 10        10       colorado -22.8375  -51.9731     20.36        86
# 19        19   puerto ayora  -0.7393  -90.3518     22.98        82
# ..       ...            ...      ...       ...       ...       ...
# 552      552  bambanglipuro  -7.9500  110.2833     24.88        87
# 563      563       ilhabela -23.7781  -45.3581     22.67        88
# 567      567      sangamner  19.5667   74.2167     23.82        85
# 569      569         ranong   9.9658   98.6348     24.34        93
# 576      576           poum -20.2333  164.0167     23.91        79
#
#      Cloudiness  Wind Speed Country        Date                     geometry
# 0            21        2.60      SA  1666108228    POINT (42.45090 18.38510)
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

# Select the desired columns and create a new DataFrame
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()
hotel_df

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = " "

# Display sample data
hotel_df.head(20)
# Out:
#             City Country      Lat       Lng  Humidity Hotel Name
# 0           faya      SA  18.3851   42.4509        35
# 1        farsund      NO  58.0948    6.8047       100
# 2    new norfolk      AU -42.7826  147.0587        58
# 3      jamestown      US  42.0970  -79.2353        77
# 4        lanzhou      CN  36.0564  103.7922        48
# 5        ushuaia      AR -54.8000  -68.3000        81
# 6         albany      US  42.6001  -73.9662        74
# 7      carnarvon      AU -24.8667  113.6333        76
# 8       sisimiut      GL  66.9395  -53.6735        98
# 9   saint-pierre      RE -21.3393   55.4781        68
# 10      colorado      BR -22.8375  -51.9731        86
# 11    nikolskoye      RU  59.7035   30.7861        90
# 12        trairi      BR  -3.2778  -39.2689        51
# 13     dobryanka      RU  58.4619   56.4165        93
# 14       qaanaaq      GL  77.4840  -69.3632        74
# 15       mataura      NZ -46.1927  168.8643        96
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
import json

# Loop through the cities and find the first hotel
for index, row in hotel_df.iterrows():
    lat = row['Lat']
    lng = row['Lng']
    url = f'https://api.geoapify.com/v2/places?lat={lat}&lon={lng}&categories=accommodation.hotel&radius=10000&limit=1&apiKey={geoapify_key}'
    #print(url)
    response = requests.get(url)
    if response.status_code == 200:
        result = response.json()
        #print("I am here")
        if 'features' in result and len(result['features']) > 0:
            try:
                hotel_name = result['features'][0]['properties']['name']
                hotel_df.at[index, 'Hotel Name'] = hotel_name
                #print("I am here too")
            except (KeyError, IndexError):
#         # If no hotel is found, set the hotel name as "No hotel found".
                 hotel_df.loc[index, "Hotel Name"] = "No hotel found"
            #hotel_df
    else:
        print(response)

# Print the updated data frame
hotel_df
# Out:
#             City Country      Lat       Lng  Humidity  \
# 0           faya      SA  18.3851   42.4509        35
# 1        farsund      NO  58.0948    6.8047       100
# 2    new norfolk      AU -42.7826  147.0587        58
# 3      jamestown      US  42.0970  -79.2353        77
# 4        lanzhou      CN  36.0564  103.7922        48
# ..           ...     ...      ...       ...       ...
# 572    sovetskiy      RU  61.3614   63.5842        96
# 573      tatarsk      RU  55.2190   75.9828        89
# 574    canchungo      GW  12.0672  -16.0333        61
# 575      iquique      CL -20.2208  -70.1431        68
# 576         poum      NC -20.2333  164.0167        79
#
#                     Hotel Name
# 0          فندق إنتركونتيننتال
# 1              Rederiet Hotell
# 2    Woodbridge on the Derwent
# 3         DoubleTree Jamestown
# 4                         西园宾馆
# ..                         ...
# 572                  Кировская
# 573             Постоялый двор
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Set the plotting backend to Bokeh
hv.extension('bokeh')

# Configure the map plot
map_plot_1 = hotel_df.hvplot.points(
    geo=True,
    x='Lng',
    y='Lat',
    size='Humidity',
    title='City Humidity Map',
    hover_cols=['City', 'Humidity', 'Hotel Name'],
    color='Humidity',
    cmap='viridis_r',
    alpha=0.3,
    tiles="OSM"
)

# Display the map
map_plot_1.opts(width=1000, height=800)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Hotel Name)
